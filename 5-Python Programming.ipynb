# %%
# %pip install requests
# Out:
# ...
# WARNING: Error parsing requirements for slicer: [Errno 2] No such file or directory: '/opt/anaconda3/lib/python3.8/site-packages/slicer-0.0.7.dist-info/METADATA'

# %%
import requests

# %%
requests.get('https://api.github.com/')
# Out:
# <Response [200]>

# %%
# Response [200] = OK, Sucessful

# %%
#import the library used to query a website
import requests

import pandas as pd
 
#import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup

#specify the url
quotes = "https://www.goodreads.com/quotes"

#Query the website/url and return the html to the variable 'page'
page = requests.get(quotes)

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html class="desktop\n">\n<head>\n  <title>Popular Quotes</title>\n\n<meta content="Popular quotes from Goodreads members. Oscar Wilde: ‘Be yourself; everyone else is already taken.’, Marilyn Monroe: ‘I\'m selfish, impatient and a little ..." name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/quotes\' rel=\'canonical\'>\n\n\n\n  \n\n          <script type="text/javascript">\n        if (window.Mobvious === undefined) {\n          window.Mobvious = {};\n        }\n        window.Mobvious.device_type = \'desktop\';\n        </script>\n\n\n  \n<script src="https://s.gr-assets.com/assets/webfontloader-f5925439393a000d48096973793890d8.js"></script>\n<script>\n//<![CDATA[\n\n  WebFont.load({\n    classes: false,\n    custom: {\n      families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],\n      urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]\n    }\n  });\n\n//]]>\n
# ...

# %%
#Fetching the contents of the website as a document
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="desktop">
# <head>
# <title>Popular Quotes</title>
# <meta content="Popular quotes from Goodreads members. Oscar Wilde: ‘Be yourself; everyone else is already taken.’, Marilyn Monroe: ‘I'm selfish, impatient and a little ..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.goodreads.com/quotes" rel="canonical"/>
# <script type="text/javascript">
#         if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#         </script>
# <script src="https://s.gr-assets.com/assets/webfontloader-f5925439393a000d48096973793890d8.js"></script>
# <script>
# //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
# </script>
# ...

# %%
#Find all the lines in the document whose class was quoteDetails which has all
#the details of the quotes - Authorname, quote
quote_text=soup.find_all(class_="quoteDetails")

# %%
quote_text
# Out:
# [<div class="quoteDetails">
#  <a class="leftAlignedImage" href="/author/show/3565.Oscar_Wilde">
#  <img alt="Oscar Wilde" src="https://images.gr-assets.com/authors/1521044377p2/3565.jpg"/>
#  </a>
#  <div class="quoteText">
#        “Be yourself; everyone else is already taken.”
#    <br/>  ―
#    <span class="authorOrTitle">
#      Oscar Wilde
#    </span>
#  </div>
#  <div class="quoteFooter">
#  <div class="greyText smallText left">
#       tags:
#         <a href="/quotes/tag/attributed-no-source">attributed-no-source</a>,
#         <a href="/quotes/tag/be-yourself">be-yourself</a>,
#         <a href="/quotes/tag/honesty">honesty</a>,
#         <a href="/quotes/tag/inspirational">inspirational</a>,
#         <a href="/quotes/tag/misattributed-oscar-wilde">misattributed-oscar-wilde</a>
#  </div>
#  <div class="right">
#  <a class="smallText" href="/quotes/19884-be-yourself-everyone-else-is-already-taken" title="View this quote">155660 likes</a>
#  </div>
#  </div>
#  </div>,
# ...

# %%
#Fetching the contents of the website as a document
soup = BeautifulSoup(page.text, 'html.parser')

#Find all the lines in the document whose class was quoteDetails which has all
#the details of the quotes - Authorname, quote
quote_text=soup.find_all(class_="quoteDetails")

#Creating an empty dataframe to store the retrieved details
df1=pd.DataFrame()

# %%
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Loop to fetch each of the category- Authorname,quote separately and prints them.
for text1 in quote_text:
      
      #Fetch the author name when it finds the class as authorOrTitle.
      #Fetch the quote when it finds the class as quoteText.
      #Fetch the likes when it finds the class as right.
      likes=text1.find(class_="right")
      num_like=likes.find('a')
      for num_likenew in num_like:
          author_name=text1.find_all(class_="authorOrTitle")
          quotetext=text1.find_all(class_="quoteText")
          for qu in quotetext:
                for names in author_name:
                    #Appending the data to the dataframe
                    df1 = df1.append({'Authorname': names.contents[0].replace('\n',''),
                                       "Quote" : qu.contents[0].replace('\n',''),
                                       "Likes": num_likenew },
                                        ignore_index=True)

print(df1.head())
#Storing the data to a csv file
df1.to_csv("Extracted Quotes.csv")
# Out:
#                     Authorname         Likes  \
# 0                Oscar Wilde    155660 likes
# 1             Marilyn Monroe    154755 likes
# 2            Albert Einstein    136638 likes
# 3                Frank Zappa    133592 likes
# 4      Marcus Tullius Cicero    124570 likes
#
#                                                Quote
# 0        “Be yourself; everyone else is already t...
# 1        “I'm selfish, impatient and a little ins...
# 2        “Two things are infinite: the universe a...
# 3                 “So many books, so little time.”
# 4        “A room without books is like a body wit...

# %%
df1.head(20)
# Out:
#                              Authorname         Likes  \
# 0                         Oscar Wilde    155660 likes
# 1                      Marilyn Monroe    154755 likes
# 2                     Albert Einstein    136638 likes
# 3                         Frank Zappa    133592 likes
# 4               Marcus Tullius Cicero    124570 likes
# 5                   Bernard M. Baruch    123437 likes
# 6                   William W. Purkey    121369 likes
# 7                           Dr. Seuss    118209 likes
# 8                            Mae West    110965 likes
# 9                      Mahatma Gandhi    109118 likes
# 10                       Robert Frost    103305 likes
# 11                      J.K. Rowling,     98152 likes
# 12  Harry Potter and the Goblet of Fire   98152 likes
# 13                       Albert Camus     87851 likes
# 14                         Mark Twain     86326 likes
# 15                        C.S. Lewis,     85290 likes
# ...

# %%
from getpass import getpass

# %%
#requests.get('ServerName/port',
 #           auth=('username',
  #               gatepass()))

# %%
# Restful API:
# REST-

# %%
# %pip install joblib
# Out:
# ...
# WARNING: Error parsing requirements for slicer: [Errno 2] No such file or directory: '/opt/anaconda3/lib/python3.8/site-packages/slicer-0.0.7.dist-info/METADATA'

# %%
import joblib
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


iris_df = datasets.load_iris()

x = iris_df.data
y = iris_df.target

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
dt = DecisionTreeClassifier().fit(X_train, y_train)
preds = dt.predict(X_test)

accuracy = accuracy_score(y_test, preds)
joblib.dump(dt, 'iris-model.model')
print('Model Training Finished.\n\tAccuracy obtained: {}'.format(accuracy))
# Out:
# Model Training Finished.
# 	Accuracy obtained: 0.9210526315789473

# %%
import numpy as np
x1 = np.array([[5.1, 3.5, 1.4, 0.2],
       [4.9, 3. , 1.4, 0.2],
       [4.7, 3.2, 1.3, 0.2],
       [4.6, 3.1, 1.5, 0.2],
       [5. , 3.6, 1.4, 0.2],
       [5.4, 3.9, 1.7, 0.4],
       [5.6, 0.4, 0.4, 4.3],
       [5. , 3.4, 1.5, 0.2],
       [4.4, 2.9, 1.4, 0.2]])

# %%
x1
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [5.6, 0.4, 0.4, 4.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2]])

# %%
dt.predict(x1)
# Out:
# array([0, 0, 0, 0, 0, 0, 2, 0, 0])

# %%
import os
os.getcwd()
# Out:
# '/Users/pradmishra/Desktop/Reva University/MTech in AI Course/AI-01 Batch'

# %%
loaded_model = joblib.load('iris-model.model')

# %%
loaded_model.predict(x1)
# Out:
# array([0, 0, 0, 0, 0, 0, 2, 0, 0])

# %%
# Inheritance methods

# %%
class Parent: # class
    parentAttr = 100
    def __init__(self): # constructor
        print('calling the parent constructor')
    def parentMethod(self): 
        print('calling the parent method')
    def setAttr(self,attr): # method
        Parent.parentAttr = attr # instance attribute
    def getAttr(self):
        print(Parent.parentAttr)

# %%
class Child(Parent):
    def __init__(self):
        print('calling the child constructor')
        
    def childMethod(self):
        print('calling the child method')

# %%
c = Child() # this is an instance of child
# Out:
# calling the child constructor

# %%
c.childMethod()
# Out:
# calling the child method

# %%
c.parentMethod()
# Out:
# calling the parent method

# %%
c.setAttr(1000)

# %%
c.getAttr()
# Out:
# 1000

# %%
# Four types of Inheritance
# single inheritance
# Multiple Inheritance
# Multilevel Inheritance
# hierachical inheritance

# %%
###without inheritance
class A:
    def model1():
        pass
    def model2():
        pass

# %%
class B:
    def model1():
        pass
    def model2():
        pass
    def model3():
        pass
    def model4():
        pass

# %%
###without inheritance
class A:
    def model1():
        pass
    def model2():
        pass
    
class B:
    def model1():
        pass
    def model2():
        pass
    def model3():
        pass
    def model4():
        pass
    
class C:
    def model1():
        pass
    def model2():
        pass
    def model3():
        pass
    def model4():
        pass
    def model5():
        pass
    def model6():
        pass

# %%
# with inheritance
class A: #parent
    def m1(self):
        print('Class-A : Method-1')
    def m2(self):
        print('Class-A : Method-2')

class B(A): #child
    def m3(self):
        print('Class-B : Method-3')
    def m4(self):
        print('Class-B : Method-4')
        
class C(B): #sub-child
    def m5(self):
        print('Class-C : Method-5')
    def m6(self):
        print('Class-C : Method-6')

# %%
a = A()
b = B()
c = C()

# %%
# How many methods does each class contains now?

# %%
a.m1()
# Out:
# Class-A : Method-1

# %%
a.m2()
# Out:
# Class-A : Method-2

# %%
b.m3()
# Out:
# Class-B : Method-3

# %%
b.m1()
# Out:
# Class-A : Method-1

# %%
c.m1()
# Out:
# Class-A : Method-1

# %%
# Multiple Inheritance
# with inheritance
class A:
    def m1(self):
        print('Class-A : Method-1')
    def m2(self):
        print('Class-A : Method-2')

class B:
    def m3(self):
        print('Class-B : Method-3')
    def m4(self):
        print('Class-B : Method-4')
        
class C(A,B):   #multiple
    def m5(self):
        print('Class-C : Method-5')
    def m6(self):
        print('Class-C : Method-6')

# %%
a.m1()
# Out:
# Class-A : Method-1

# %%
b.m3()
# Out:
# Class-B : Method-3

# %%
c.m5()
# Out:
# Class-C : Method-5

# %%
c.m3()
# Out:
# Class-B : Method-3

# %%
# polymorphisim is a way of using same function on objects of different classes/types
# in the following exxample

# we tried score (a function) on an interger, list, list of string, string etc.

# %%
def score(math, stat):
    return (math + stat)

# %%
score(10,34) #integer
# Out:
# 44

# %%
score([10,20,30],[32,31,34]) #list of integers
# Out:
# [10, 20, 30, 32, 31, 34]

# %%
score(['prob','average','median'],['algebra','eigen','matrix']) #list of strings
# Out:
# ['prob', 'average', 'median', 'algebra', 'eigen', 'matrix']

# %%
score(['predicting'],['probability']) #strings
# Out:
# ['predicting', 'probability']

# %%
# defualt: no default
# 0.80 : 0.20

# %%
# 0.51-0.49

# %%
# Aarya
# Arya

# %%
jsdata = '''{
    "quiz": {
        "sport": {
            "q1": {
                "question": "Which one is correct team name in NBA?",
                "options": [
                    "New York Bulls",
                    "Los Angeles Kings",
                    "Golden State Warriros",
                    "Huston Rocket"
                ],
                "answer": "Huston Rocket"
            }
        },
        "maths": {
            "q1": {
                "question": "5 + 7 = ?",
                "options": [
                    "10",
                    "11",
                    "12",
                    "13"
                ],
                "answer": "12"
            },
            "q2": {
                "question": "12 - 8 = ?",
                "options": [
                    "1",
                    "2",
                    "3",
                    "4"
                ],
                "answer": "4"
            }
        }
    }
}'''

# %%
jsdata
# Out:
# '{\n    "quiz": {\n        "sport": {\n            "q1": {\n                "question": "Which one is correct team name in NBA?",\n                "options": [\n                    "New York Bulls",\n                    "Los Angeles Kings",\n                    "Golden State Warriros",\n                    "Huston Rocket"\n                ],\n                "answer": "Huston Rocket"\n            }\n        },\n        "maths": {\n            "q1": {\n                "question": "5 + 7 = ?",\n                "options": [\n                    "10",\n                    "11",\n                    "12",\n                    "13"\n                ],\n                "answer": "12"\n            },\n            "q2": {\n                "question": "12 - 8 = ?",\n                "options": [\n                    "1",\n                    "2",\n                    "3",\n                    "4"\n                ],\n                "answer": "4"\n            }\n        }\n    }\n}'

# %%
import json
data = json.loads(jsdata)

# %%
data
# Out:
# {'quiz': {'sport': {'q1': {'question': 'Which one is correct team name in NBA?',
#     'options': ['New York Bulls',
#      'Los Angeles Kings',
#      'Golden State Warriros',
#      'Huston Rocket'],
#     'answer': 'Huston Rocket'}},
#   'maths': {'q1': {'question': '5 + 7 = ?',
#     'options': ['10', '11', '12', '13'],
#     'answer': '12'},
#    'q2': {'question': '12 - 8 = ?',
#     'options': ['1', '2', '3', '4'],
#     'answer': '4'}}}}

# %%
import pandas as pd
pd.json_normalize(data,max_level=None)
# Out:
#                    quiz.sport.q1.question  \
# 0  Which one is correct team name in NBA?
#
#                                quiz.sport.q1.options quiz.sport.q1.answer  \
# 0  [New York Bulls, Los Angeles Kings, Golden Sta...        Huston Rocket
#
#   quiz.maths.q1.question quiz.maths.q1.options quiz.maths.q1.answer  \
# 0              5 + 7 = ?      [10, 11, 12, 13]                   12
#
#   quiz.maths.q2.question quiz.maths.q2.options quiz.maths.q2.answer
# 0             12 - 8 = ?          [1, 2, 3, 4]                    4

# %%
# Multithreading vs. Multiprocessing

# %% [markdown]
# Multithreading in Python or Threading in python is a concept by which mutliple threads are launched in the same process to achieve parallelism and multitasking within the same application. Executing different threads are equivalent to executing different programs or different functions within the same process.

# %% [markdown]
# a GUI such as Pycharm or a Jupyter Notebook keeps autosaving your code as and when you make changes, which clearly illustrates multiple tasks being performed within the same process.

# %%
# Multithreading: multiple tasks are run within the same process
# multiprocessing is where two or more processes run in a single application without having a shared state within 
# them because they run as different independent processes

# %%
import threading
import requests

def connect_to_urls(urls):
    for url in urls:
        r = requests.get(url)
        print(f"{url} - Status: {r.status_code}")

# %%
if __name__ == '__main__':
    
    url_list = ['https://google.com', 
                'https://youtube.com', 
                'https://wikipedia.com', 
                'https://medium.com',
               'https://reva.edu.in/']
    print(f"URL List: {url_list}")
    
    t1 = threading.Thread(target=connect_to_urls, args=(url_list[:2],)) # Create Thread 1
    t2 = threading.Thread(target=connect_to_urls, args=(url_list[2:],)) # Create Thread 2

    t1.start()  # Thread 1 starts here
    t2.start()  # Thread 2 starts here
# Out:
# URL List: ['https://google.com', 'https://youtube.com', 'https://wikipedia.com', 'https://medium.com', 'https://reva.edu.in/']
# https://google.com - Status: 200
# https://youtube.com - Status: 200
# https://wikipedia.com - Status: 200
# https://medium.com - Status: 200
# https://reva.edu.in/ - Status: 200

# %%
import threading #import lib

# %%
threading.current_thread() # current executing thread
# Out:
# <_MainThread(My_Py_Thread, started 4687273472)>

# %%
threading.current_thread().getName() #name of the thread
# Out:
# 'My_Py_Thread'

# %%
(threading.current_thread().ident) #identification number of the thread
# Out:
# 4687273472

# %%
from threading import *

# %%
current_thread().getName()
# Out:
# 'My_Py_Thread'

# %%
current_thread().setName('My_Py_Thread')

# %%
current_thread().getName()
# Out:
# 'My_Py_Thread'

# %%
from threading import *

# %%
def display():
    print('Child Executing the thread: ',current_thread().getName())

# %%
t = Thread(target=display) # the main thread creates a child thread object to process

# %%
t.start()
# Out:
# Child Executing the thread:  Thread-17

# %%
current_thread().getName()
# Out:
# 'My_Py_Thread'

# %%
def display():
    for i in range(10):
        print('Child Thread')
t = Thread(target=display)
t.start()

for i in range(10):
    print('Main Thread')
# Out:
# Child ThreadMain Thread
# Child Thread
# Child Thread
# Child Thread
# Child Thread
# Child Thread
# Child Thread
# Child Thread
# Child Thread
# Child Thread
#
# Main Thread
# Main Thread
# Main Thread
# Main Thread
# Main Thread
# Main Thread
# Main Thread
# Main Thread
# Main Thread

# %%
class MyThread(Thread):
    def run(self):
        print('Child executing thread: ',current_thread().getName())

# %%
t = MyThread()

# %%
t.start()
# Out:
# Child executing thread:  Thread-19

# %%
current_thread().getName()
# Out:
# 'My_Py_Thread'

# %%
# Without Multi-threading

# %%
from threading import*
import time

def display():
    print('Starting',current_thread().getName())
    time.sleep(3)
    print('Ending',current_thread().getName())

print('Active Threads',active_count())

t1 = Thread(target=display,name='1st Thread')

t2 = Thread(target=display,name='2nd Thread')

t3 = Thread(target=display,name='3rd Thread')

t1.start()

t2.start()

t3.start()

print(t1.name,'is',t1.is_alive())

enum = enumerate()

for t in enum:
    print(t.name)
    
print(active_count())

time.sleep(5)

print(active_count())

print(t1.name,'is',t1.is_alive())
# Out:
# Active Threads 6
# Starting 1st Thread
# StartingStarting1st Thread 3rd Thread
#  2nd Thread
#  is True
# My_Py_Thread
# Thread-2
# Thread-3
# IPythonHistorySavingThread
# Thread-1
# Thread-4
# 1st Thread
# 2nd Thread
# 3rd Thread
# 9
# Ending 1st Thread
# EndingEnding 3rd Thread
#  2nd Thread
# 6
# 1st Thread is False

# %%
def double(num):
    for n in num:
        time.sleep(1)
        print('Double:', 2*n)
        
def square(num):
    for n in num:
        time.sleep(1)
        print('Square:',n*n)
        
num = [11,12,13,14,15,16]

starttime = time.time()

double(num)

square(num)

endtime = time.time()

print('Time Taken by the Program:', endtime-starttime)
# Out:
# Double: 22
# Double: 24
# Double: 26
# Double: 28
# Double: 30
# Double: 32
# Square: 121
# Square: 144
# Square: 169
# Square: 196
# Square: 225
# Square: 256
# Time Taken by the Program: 12.06906270980835

# %%
# With Multithreading

# %%
def double(num):
    for n in num:
        time.sleep(1)
        print('Double:', 2*n)
        
def square(num):
    for n in num:
        time.sleep(1)
        print('Square:',n*n)
        
num = [11,12,13,14,15,16]

starttime = time.time()

#double(num)
t1 = Thread(target=double,args=(num,))

#square(num)
t2 = Thread(target=square,args=(num,))

t1.start()

t2.start()

t1.join()

t2.join()

endtime = time.time()

print('Time Taken by the Program:', endtime-starttime)
# Out:
# Double:Square: 22
#  121
# Double:Square: 24
#  144
# Square:Double: 169
#  26
# Square:Double: 196
#  28
# Square:Double: 30
#  225
# Double:Square: 32
#  256
# Time Taken by the Program: 6.03275990486145

# %%
# some more examples

# %%
import threading
def new():
    for x in range(6):
        print("Child Thread Here!!")
t1=threading.Thread(target=new)

# %%
t1
# Out:
# <Thread(Thread-22, initial)>

# %%
t1.start()
t1.join()
print("Main Thread Here!!")
# Out:
# Child Thread Here!!
# Child Thread Here!!
# Child Thread Here!!
# Child Thread Here!!
# Child Thread Here!!
# Child Thread Here!!
# Main Thread Here!!

# %%
import threading
import time

# %%
import time
import threading


def calc_square(numbers):
    print("Calculate square numbers: ")
    for i in numbers:
        time.sleep(2)  # artificial time-delay
        print('square: ', str(i * i))


def calc_cube(numbers):
    print("Calculate cube numbers: ")
    for i in numbers:
        time.sleep(2)
        print('cube: ', str(i * i * i))


if __name__ == "__main__":
    arr = [2, 3, 8, 9]
    t1 = threading.Thread(target=calc_square, args=(arr,))
    t2 = threading.Thread(target=calc_cube, args=(arr,))
    # creating two threads here t1 & t2
    t1.start()
    t2.start()
    # starting threads here parallel by using start function.
    t1.join()
    # this join() will wait until the cal_square() function is finished.
    t2.join()
    # this join() will wait unit the cal_cube() function is finished.
    print("Successes!")
# Out:
# Calculate square numbers:
# Calculate cube numbers:
# square: cube:  8
#  4
# cube:  27
# square:  9
# cube:  512
# square:  64
# cube: square:  81
#  729
# Successes!

# %%
import time
import multiprocessing


def calc_square(numbers):
    for i in numbers:
        time.sleep(3)  # artificial time-delay
        print('square: ', str(i * i))


def calc_cube(numbers):
    for i in numbers:
        time.sleep(3)
        print('cube: ', str(i * i * i))


if __name__ == "__main__":
    arr = [2, 3, 8, 9]
    p1 = multiprocessing.Process(target=calc_square, args=(arr,))
    p2 = multiprocessing.Process(target=calc_cube, args=(arr,))
    # creating two Process here p1 & p2
    p1.start()
    p2.start()
    # starting Processes here parallel by using start function.
    p1.join()
    # this join() will wait until the calc_square() function is finished.
    p2.join()
    # this join() will wait unit the calc_cube() function is finished.
    print("Successes!")
# Out:
# Successes!

# %%
import multiprocessing
results = []   #Creating a Global Variable
def calc_square(numbers):
   global results
   for i in numbers:
      print('square: ', str(i*i))
      results.append(i*i)
      print('witnin a result: '+str(results))
if __name__ == "__main__":
    arr = [2,3,8,9]
    p1 = multiprocessing.Process(target = calc_square,args=(arr,))
    # creating one Process here p1
    p1.start()
    # starting Processes here parallel by using start function.
    p1.join()
    # this join() will wait until the calc_square() function is    finished.
    print('result : '+str(results))
#this print didn't work here we have to print it within the process
    print("Successed!")
# Out:
# result : []
# Successed!

# %%
import multiprocessing
def calc_square(numbers, q):   #child-function
    for i in numbers:
        q.put(i*i)
print('inside process : '+str(results))
# Out:
# inside process : []

# %%
if __name__ == "__main__":   #main function
    arr = [2,3,8,9]
    q = multiprocessing.Queue()
    p1 = multiprocessing.Process(target = calc_square,args=(arr, q))
    p1.start()
    p1.join()
    while q.empty() is False:
        print(q.get())

# %%
# import requests
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
#get GitHub’s public timeline

# %%
# make an HTTP POST request

# %%
r = requests.post('https://httpbin.org/post', data = {'key':'value'})
r
# Out:
# <Response [200]>

# %%
r = requests.put('https://httpbin.org/put', data = {'key':'value'})
r
# Out:
# <Response [200]>

# %%
r = requests.delete('https://httpbin.org/delete')

# %%
r
# Out:
# <Response [200]>

# %%
r = requests.head('https://httpbin.org/get')

# %%
r
# Out:
# <Response [200]>

# %%
r = requests.options('https://httpbin.org/get')

# %%
r
# Out:
# <Response [200]>

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
payload
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
r = requests.get('https://httpbin.org/get', params=payload)
r
# Out:
# <Response [200]>

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %%
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"16366550553","type":"PullRequestEvent","actor":{"id":70693642,"login":"onni2","display_login":"onni2","gravatar_id":"","url":"https://api.github.com/users/onni2","avatar_url":"https://avatars.githubusercontent.com/u/70693642?"},"repo":{"id":363903696,"name":"TomasOrripet/verk_2Cereal","url":"https://api.github.com/repos/TomasOrripet/verk_2Cereal"},"payload":{"action":"opened","number":132,"pull_request":{"url":"https://api.github.com/repos/TomasOrripet/verk_2Cereal/pulls/132","id":644865500,"node_id":"MDExOlB1bGxSZXF1ZXN0NjQ0ODY1NTAw","html_url":"https://github.com/TomasOrripet/verk_2Cereal/pull/132","diff_url":"https://github.com/TomasOrripet/verk_2Cereal/pull/132.diff","patch_url":"https://github.com/TomasOrripet/verk_2Cereal/pull/132.patch","issue_url":"https://api.github.com/repos/TomasOrripet/verk_2Cereal/issues/132","number":132,"state":"open","locked":false,"title":"laga add to cart","user":{"login":"onni2","id":70693642,"node_id":"MDQ6VXNlcjcwNjkzNjQy","avatar_url":"
# ...

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.content
# Out:
# b'[{"id":"16366550553","type":"PullRequestEvent","actor":{"id":70693642,"login":"onni2","display_login":"onni2","gravatar_id":"","url":"https://api.github.com/users/onni2","avatar_url":"https://avatars.githubusercontent.com/u/70693642?"},"repo":{"id":363903696,"name":"TomasOrripet/verk_2Cereal","url":"https://api.github.com/repos/TomasOrripet/verk_2Cereal"},"payload":{"action":"opened","number":132,"pull_request":{"url":"https://api.github.com/repos/TomasOrripet/verk_2Cereal/pulls/132","id":644865500,"node_id":"MDExOlB1bGxSZXF1ZXN0NjQ0ODY1NTAw","html_url":"https://github.com/TomasOrripet/verk_2Cereal/pull/132","diff_url":"https://github.com/TomasOrripet/verk_2Cereal/pull/132.diff","patch_url":"https://github.com/TomasOrripet/verk_2Cereal/pull/132.patch","issue_url":"https://api.github.com/repos/TomasOrripet/verk_2Cereal/issues/132","number":132,"state":"open","locked":false,"title":"laga add to cart","user":{"login":"onni2","id":70693642,"node_id":"MDQ6VXNlcjcwNjkzNjQy","avatar_url":
# ...

# %%
r.json()
# Out:
# [{'id': '16366550553',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 70693642,
#    'login': 'onni2',
#    'display_login': 'onni2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/onni2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70693642?'},
#   'repo': {'id': 363903696,
#    'name': 'TomasOrripet/verk_2Cereal',
#    'url': 'https://api.github.com/repos/TomasOrripet/verk_2Cereal'},
#   'payload': {'action': 'opened',
#    'number': 132,
#    'pull_request': {'url': 'https://api.github.com/repos/TomasOrripet/verk_2Cereal/pulls/132',
#     'id': 644865500,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjQ0ODY1NTAw',
#     'html_url': 'https://github.com/TomasOrripet/verk_2Cereal/pull/132',
#     'diff_url': 'https://github.com/TomasOrripet/verk_2Cereal/pull/132.diff',
#     'patch_url': 'https://github.com/TomasOrripet/verk_2Cereal/pull/132.patch',
#     'issue_url': 'https://api.github.com/repos/TomasOrripet/verk_2Cereal/issues/132',
# ...

# %%
r = requests.get('https://api.github.com/events', stream=True)

# %%
r.raw

# %%
# want to send some form-encoded data

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
r = requests.post("https://httpbin.org/post", data=payload)

# %%
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-609eb21a-4b403d595d33bc1e2a8d3caf"
#   },
#   "json": null,
#   "origin": "49.207.214.61",
#   "url": "https://httpbin.org/post"
# }

# %%
# The data argument can also have multiple values for each key

# %%
payload_tuples = [('key1', 'value1'), ('key1', 'value2')]

# %%
r1 = requests.post('https://httpbin.org/post', data=payload_tuples)
print(r1.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-609eb21b-74daf817164d633c013b8e66"
#   },
#   "json": null,
#   "origin": "49.207.214.61",
#   "url": "https://httpbin.org/post"
# }

# %%
payload_dict = {'key1': ['value1', 'value2']}

# %%
r2 = requests.post('https://httpbin.org/post', data=payload_dict)
print(r2.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-609eb21c-25487f6114a0132f37ed9de1"
#   },
#   "json": null,
#   "origin": "49.207.214.61",
#   "url": "https://httpbin.org/post"
# }

# %%
if r.status_code == 200:
    print('Success!')
elif r.status_code == 404:
    print('Not Found.')
# Out:
# Success!

# %%
# One example of an API that requires authentication is GitHub’s Authenticated User API

# %%
from getpass import getpass

# %%
requests.get('https://api.github.com/user', auth=('username', getpass()))
# Out:
# ········
# <Response [401]>

# %%
requests.get('https://api.github.com', timeout=1)
# Out:
# <Response [200]>

# %%
requests.get('https://api.github.com', timeout=3.05)
# Out:
# <Response [200]>

# %%
requests.get('https://api.github.com', timeout=(2, 5))
# Out:
# <Response [200]>

# %%
import requests
from getpass import getpass

# By using a context manager, you can ensure the resources used by
# the session will be released after use
with requests.Session() as session:
    session.auth = ('username', getpass())

    # Instead of requests.get(), you'll use session.get()
    response = session.get('https://api.github.com/user')

# You can inspect the response just like you did before
print(response.headers)
print(response.json())
# Out:
# ········
# ...

# %% [markdown]
# Below are some key differences,
#
#     Multiprocessing launches different processes which are independent to each other. On the other hand, multithreading launches threads which are still dependent on the parent process.
#
#     Each Process in Multiprocessing has its own CPU Power and memory which is distinct to each process. Whereas, in multithreading the individual threads utilize the same resources(CPU + Memory) present in the parent process.
#
#     If any process fails due to an exception, the other processes would still be running in case of Multiprocessing. On the contrary, if any thread fails, all the other threads/tasks are terminated.
#
#     Multiprocessing requires some special objects or some sort of shared memory to access objects in different processes. In contrast to this, sharing objects/data between threads are much easier since they share the same memory space.
#
#     Multiprocessing is more suitable for CPU intensive applications, wheras Multithreading is the best fit when your applications are I/O bound.
